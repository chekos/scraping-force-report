# %% [markdown]
# # scraping force.nj.com
# #### Scraping the force.nj.com website for 2 statistics for each of the 468 police departments.
#
# <details>
#     <summary><strong>Goal</strong></summary>
#     "The goal of this notebook is to ..."
#     <ul>
#         <li> measurable goals for this notebook </li>
#         <li> Ex 1: Identify <i>variables of interest in dataset <strong>name.dta</strong></i> </li>
#         <li> Ex 2: Create a <i>working dataset</i> from raw data.</li>
#     </ul>
# </details>
#
# <details>
#     <summary><strong>Context</strong></summary>
#     Context at the moment (i.e. "We've downloaded raw data from <strong><i>website.com</i></strong> and are now in the process of creating a mastefile.")
#     <li> What is the final goal of this project?</li>
#     <li> What are we trying to recreate? Where are we in the process?</li>
#     <li> Any links to documentation / figures.</li>
# </details>

# %%
import pandas as pd
import requests
from pathlib import Path
from tools import tree
from datetime import datetime as dt
from bs4 import BeautifulSoup
today = dt.today().strftime("%d-%b-%y")

today
# Out:
# '12-Jun-20'

# %%
RAW_DATA = Path("../data/raw/")
INTERIM_DATA = Path("../data/interim/")
PROCESSED_DATA = Path("../data/processed/")
FINAL_DATA = Path("../data/final/")

# %%
tree(RAW_DATA)
# Out:
# + ../data/raw

# %%
BASE_URL = "http://force.nj.com"

# %%
test_url = BASE_URL + "/database/pd-dept/brick-ocean"

# %%
r = requests.get(test_url)

# %%
soup = BeautifulSoup(r.content)

# %%
datalist = soup.findAll("datalist")[0]

# %%
tst = datalist.findAll("option")[0]

# %%
tst.attrs['value']
# Out:
# '/database/pd-dept/aberdeen-monmouth'

# %%
tst.text.strip()
# Out:
# 'Aberdeen, Monmouth'

# %%
data = []
for option in datalist.findAll("option"):
    depts = {}
    depts['name'] = option.text.strip()
    depts['url'] = option.attrs['value']
    data.append(depts)

# %%
df = pd.DataFrame(data)

# %%
df['full_url'] = 'http://force.nj.com' + df['url']

# %%
df.head()
# Out:
#                    name                                    url  \
# 0    Aberdeen, Monmouth    /database/pd-dept/aberdeen-monmouth
# 1     Absecon, Atlantic     /database/pd-dept/absecon-atlantic
# 2     Allendale, Bergen     /database/pd-dept/allendale-bergen
# 3  Allenhurst, Monmouth  /database/pd-dept/allenhurst-monmouth
# 4   Allentown, Monmouth   /database/pd-dept/allentown-monmouth
#
#                                             full_url
# 0  http://force.nj.com/database/pd-dept/aberdeen-...
# 1  http://force.nj.com/database/pd-dept/absecon-a...
# 2  http://force.nj.com/database/pd-dept/allendale...
# 3  http://force.nj.com/database/pd-dept/allenhurs...
# 4  http://force.nj.com/database/pd-dept/allentown...

# %%
def get_likelihood_numbers(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content)
    
    try:
        important_nums = soup.find_all("section", "racial_breakdown")[0].find_all("div", "important_num1")
    except:
        important_nums = f"Error found for {url}"
    
    return important_nums

# %%
important_numbers = df['full_url'].apply(get_likelihood_numbers)

# %%
important_numbers.apply(type).value_counts(dropna=False)
# Out:
# <class 'bs4.element.ResultSet'>    461
# <class 'str'>                       86
# Name: full_url, dtype: int64

# %%
def extract_numbers(row):
    if type(row) == "<class 'str'>":
        pass
    else:
        numbers = []
        for element in row:
            print(row)
            numbers.append(element.strip())
    if numbers:
        return numbers
    else:
        return row

# %%
important_numbers.apply(extract_numbers)
# Out:
# [<div class="important_num1">
#
#
#               294%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               42%
#
#
#
#             </div>]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-254319ed77e7> in <module>
# ----> 1 important_numbers.apply(extract_numbers)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-106-10b2b369e960> in extract_numbers(row)
#       6         for element in row:
#       7             print(row)
# ----> 8             numbers.append(element.strip())
#       9     if numbers:
#      10         return numbers
#
# TypeError: 'NoneType' object is not callable

# %%
for number in important_numbers:
    print(number)
# Out:
# [<div class="important_num1">
#
#
#               294%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               42%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               583%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               68%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                8%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               2%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               96%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               39%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                35%
#
#             </div>, <div class="important_num1">
#
#
#               3%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               335%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               69%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               216%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               9%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               1147%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               4%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               108%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               3%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               78%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               286%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               717%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               63%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               353%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               76%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               89%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               231%
#
#
#
#             </div>, <div class="important_num1">
#
#                47%
#
#             </div>]
# [<div class="important_num1">
#
#
#               218%
#
#
#
#             </div>, <div class="important_num1">
#
#                28%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               40%
#
#
#
#             </div>, <div class="important_num1">
#
#                17%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#                41%
#
#             </div>, <div class="important_num1">
#
#                76%
#
#             </div>]
# [<div class="important_num1">
#
#
#               529%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               14%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                36%
#
#             </div>, <div class="important_num1">
#
#                31%
#
#             </div>]
# [<div class="important_num1">
#
#
#               779%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               10%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               924%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               53%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               252%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               83%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               642%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               79%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               68%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               52%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               747%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               88%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               367%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               5%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               254%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               35%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               527%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               36%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               925%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               54%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               150%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               37%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               457%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               39%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                1%
#
#             </div>, <div class="important_num1">
#
#
#               39%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               994%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               15%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               681%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               974%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               50%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               427%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               4%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               838%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               145%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               497%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               27%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               215%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               10%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               43%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               3922%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               7%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               101%
#
#
#
#             </div>, <div class="important_num1">
#
#                17%
#
#             </div>]
# [<div class="important_num1">
#
#
#               8%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               447%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               373%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               75%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               36%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               238%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               45%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               103%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               38%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               359%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               14%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               502%
#
#
#
#             </div>, <div class="important_num1">
#
#                78%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               464%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               21%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               568%
#
#
#
#             </div>, <div class="important_num1">
#
#                45%
#
#             </div>]
# [<div class="important_num1">
#
#
#               2046%
#
#
#
#             </div>, <div class="important_num1">
#
#                23%
#
#             </div>]
# [<div class="important_num1">
#
#
#               176%
#
#
#
#             </div>, <div class="important_num1">
#
#                12%
#
#             </div>]
# [<div class="important_num1">
#
#
#               148%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               106%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                50%
#
#             </div>, <div class="important_num1">
#
#                49%
#
#             </div>]
# [<div class="important_num1">
#
#
#               118%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               29%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                52%
#
#             </div>, <div class="important_num1">
#
#                63%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               12%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               257%
#
#
#
#             </div>, <div class="important_num1">
#
#                16%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               15%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               1421%
#
#
#
#             </div>, <div class="important_num1">
#
#                14%
#
#             </div>]
# [<div class="important_num1">
#
#
#               2255%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               123%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               3199%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               33%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               312%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               34%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               276%
#
#
#
#             </div>, <div class="important_num1">
#
#                25%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               237%
#
#
#
#             </div>, <div class="important_num1">
#
#                40%
#
#             </div>]
# [<div class="important_num1">
#
#
#               181%
#
#
#
#             </div>, <div class="important_num1">
#
#                8%
#
#             </div>]
# [<div class="important_num1">
#
#                33%
#
#             </div>, <div class="important_num1">
#
#                1%
#
#             </div>]
# [<div class="important_num1">
#
#
#               74%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               28%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               10%
#
#
#
#             </div>, <div class="important_num1">
#
#                31%
#
#             </div>]
# [<div class="important_num1">
#
#
#               308%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               3%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               340%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               39%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                54%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               238%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               454%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               113%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               39%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               125%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               46%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               482%
#
#
#
#             </div>, <div class="important_num1">
#
#                2%
#
#             </div>]
# [<div class="important_num1">
#
#
#               107%
#
#
#
#             </div>, <div class="important_num1">
#
#                3%
#
#             </div>]
# [<div class="important_num1">
#
#                4%
#
#             </div>, <div class="important_num1">
#
#                25%
#
#             </div>]
# [<div class="important_num1">
#
#
#               161%
#
#
#
#             </div>, <div class="important_num1">
#
#                5%
#
#             </div>]
# [<div class="important_num1">
#
#
#               239%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               154%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               390%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               34%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               76%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               71%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               341%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               111%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               739%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               187%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               28%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               430%
#
#
#
#             </div>, <div class="important_num1">
#
#                27%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               239%
#
#
#
#             </div>, <div class="important_num1">
#
#                24%
#
#             </div>]
# [<div class="important_num1">
#
#
#               371%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               12%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                57%
#
#             </div>]
# [<div class="important_num1">
#
#
#               498%
#
#
#
#             </div>, <div class="important_num1">
#
#                30%
#
#             </div>]
# [<div class="important_num1">
#
#                72%
#
#             </div>, <div class="important_num1">
#
#                42%
#
#             </div>]
# [<div class="important_num1">
#
#
#               390%
#
#
#
#             </div>, <div class="important_num1">
#
#                13%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               223%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               2%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               324%
#
#
#
#             </div>, <div class="important_num1">
#
#                17%
#
#             </div>]
# [<div class="important_num1">
#
#
#               273%
#
#
#
#             </div>, <div class="important_num1">
#
#                43%
#
#             </div>]
# [<div class="important_num1">
#
#
#               307%
#
#
#
#             </div>, <div class="important_num1">
#
#                5%
#
#             </div>]
# [<div class="important_num1">
#
#                15%
#
#             </div>, <div class="important_num1">
#
#                28%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               123%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               20%
#
#
#
#             </div>, <div class="important_num1">
#
#                56%
#
#             </div>]
# [<div class="important_num1">
#
#
#               202%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               9%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               110%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               44%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               454%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               89%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               173%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               19%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               95%
#
#
#
#             </div>, <div class="important_num1">
#
#                24%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               92%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               1%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               354%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               77%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               2498%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               67%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                31%
#
#             </div>]
# [<div class="important_num1">
#
#
#               449%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               137%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               270%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               25%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               293%
#
#
#
#             </div>, <div class="important_num1">
#
#                32%
#
#             </div>]
# [<div class="important_num1">
#
#
#               501%
#
#
#
#             </div>, <div class="important_num1">
#
#                4%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#                92%
#
#             </div>, <div class="important_num1">
#
#                10%
#
#             </div>]
# [<div class="important_num1">
#
#
#               189%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               216%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                18%
#
#             </div>]
# [<div class="important_num1">
#
#
#               2052%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               59%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               191%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               869%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               242%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                32%
#
#             </div>]
# [<div class="important_num1">
#
#
#               100%
#
#
#
#             </div>, <div class="important_num1">
#
#                11%
#
#             </div>]
# [<div class="important_num1">
#
#
#               304%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               23%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               9%
#
#
#
#             </div>, <div class="important_num1">
#
#                40%
#
#             </div>]
# [<div class="important_num1">
#
#
#               4005%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               38%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               109%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                16%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               101%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               23%
#
#
#
#             </div>, <div class="important_num1">
#
#                65%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               511%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               556%
#
#
#
#             </div>, <div class="important_num1">
#
#                17%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               211%
#
#
#
#             </div>, <div class="important_num1">
#
#                39%
#
#             </div>]
# [<div class="important_num1">
#
#
#               73%
#
#
#
#             </div>, <div class="important_num1">
#
#                47%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               26%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               38%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               1033%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               51%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               163%
#
#
#
#             </div>, <div class="important_num1">
#
#                52%
#
#             </div>]
# [<div class="important_num1">
#
#
#               102%
#
#
#
#             </div>, <div class="important_num1">
#
#                30%
#
#             </div>]
# [<div class="important_num1">
#
#
#               143%
#
#
#
#             </div>, <div class="important_num1">
#
#                10%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               304%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               75%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               74%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               10%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               1543%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               23%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               349%
#
#
#
#             </div>, <div class="important_num1">
#
#                64%
#
#             </div>]
# [<div class="important_num1">
#
#
#               375%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               78%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               69%
#
#
#
#             </div>, <div class="important_num1">
#
#                57%
#
#             </div>]
# [<div class="important_num1">
#
#
#               396%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               9%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#                27%
#
#             </div>, <div class="important_num1">
#
#
#               46%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               180%
#
#
#
#             </div>, <div class="important_num1">
#
#                13%
#
#             </div>]
# [<div class="important_num1">
#
#                15%
#
#             </div>, <div class="important_num1">
#
#                43%
#
#             </div>]
# [<div class="important_num1">
#
#
#               270%
#
#
#
#             </div>, <div class="important_num1">
#
#                12%
#
#             </div>]
# [<div class="important_num1">
#
#
#               489%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               192%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               306%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               90%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               151%
#
#
#
#             </div>, <div class="important_num1">
#
#                7%
#
#             </div>]
# [<div class="important_num1">
#
#
#               221%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               22%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                67%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               130%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               1439%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               105%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               340%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               182%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               575%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               211%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               2104%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               138%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               94%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               521%
#
#
#
#             </div>, <div class="important_num1">
#
#                38%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               224%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               64%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               38%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               70%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               37%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               882%
#
#
#
#             </div>, <div class="important_num1">
#
#                24%
#
#             </div>]
# [<div class="important_num1">
#
#
#               4500%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               31%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               131%
#
#
#
#             </div>, <div class="important_num1">
#
#                2%
#
#             </div>]
# [<div class="important_num1">
#
#
#               357%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               103%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                19%
#
#             </div>]
# [<div class="important_num1">
#
#
#               3424%
#
#
#
#             </div>, <div class="important_num1">
#
#                31%
#
#             </div>]
# [<div class="important_num1">
#
#                22%
#
#             </div>, <div class="important_num1">
#
#                42%
#
#             </div>]
# [<div class="important_num1">
#
#
#               201%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               152%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               9%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               274%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               163%
#
#
#
#             </div>, <div class="important_num1">
#
#                47%
#
#             </div>]
# [<div class="important_num1">
#
#
#               533%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               123%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               857%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               48%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               199%
#
#
#
#             </div>, <div class="important_num1">
#
#                9%
#
#             </div>]
# [<div class="important_num1">
#
#
#               138%
#
#
#
#             </div>, <div class="important_num1">
#
#                4%
#
#             </div>]
# [<div class="important_num1">
#
#
#               615%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               91%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               627%
#
#
#
#             </div>, <div class="important_num1">
#
#                35%
#
#             </div>]
# [<div class="important_num1">
#
#
#               556%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               62%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               153%
#
#
#
#             </div>, <div class="important_num1">
#
#                12%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               18%
#
#
#
#             </div>, <div class="important_num1">
#
#                41%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               357%
#
#
#
#             </div>, <div class="important_num1">
#
#                22%
#
#             </div>]
# [<div class="important_num1">
#
#
#               916%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               102%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               194%
#
#
#
#             </div>, <div class="important_num1">
#
#                4%
#
#             </div>]
# [<div class="important_num1">
#
#
#               368%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               7%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               19%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               451%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               160%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               6%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               449%
#
#
#
#             </div>, <div class="important_num1">
#
#                19%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               297%
#
#
#
#             </div>, <div class="important_num1">
#
#                16%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               13%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               127%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               17%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               275%
#
#
#
#             </div>, <div class="important_num1">
#
#                34%
#
#             </div>]
# [<div class="important_num1">
#
#
#               223%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               99%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               8%
#
#
#
#             </div>, <div class="important_num1">
#
#                46%
#
#             </div>]
# [<div class="important_num1">
#
#
#               1021%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               56%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               76%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               35%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               581%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               138%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                57%
#
#             </div>]
# [<div class="important_num1">
#
#
#               91%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               1%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                22%
#
#             </div>, <div class="important_num1">
#
#                63%
#
#             </div>]
# [<div class="important_num1">
#
#
#               490%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               15%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               741%
#
#
#
#             </div>, <div class="important_num1">
#
#                60%
#
#             </div>]
# [<div class="important_num1">
#
#
#               59%
#
#
#
#             </div>, <div class="important_num1">
#
#                76%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               842%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               6%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                10%
#
#             </div>]
# [<div class="important_num1">
#
#
#               429%
#
#
#
#             </div>, <div class="important_num1">
#
#                25%
#
#             </div>]
# [<div class="important_num1">
#
#
#               112%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               3%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               101%
#
#
#
#             </div>, <div class="important_num1">
#
#                60%
#
#             </div>]
# [<div class="important_num1">
#
#
#               408%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               100%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               392%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               3%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                31%
#
#             </div>, <div class="important_num1">
#
#                56%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               17%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               11%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               330%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               28%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               295%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               79%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                22%
#
#             </div>]
# [<div class="important_num1">
#
#
#               268%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               78%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                48%
#
#             </div>, <div class="important_num1">
#
#                64%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               133%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               203%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               221%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               175%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               126%
#
#
#
#             </div>, <div class="important_num1">
#
#                69%
#
#             </div>]
# [<div class="important_num1">
#
#
#               3%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               92%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               206%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               33%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               114%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                0%
#
#             </div>, <div class="important_num1">
#
#                4%
#
#             </div>]
# [<div class="important_num1">
#
#
#               8%
#
#
#
#             </div>, <div class="important_num1">
#
#                18%
#
#             </div>]
# [<div class="important_num1">
#
#
#               179%
#
#
#
#             </div>, <div class="important_num1">
#
#                18%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               95%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               603%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               58%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               41%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               1289%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               13%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               1311%
#
#
#
#             </div>, <div class="important_num1">
#
#                20%
#
#             </div>]
# [<div class="important_num1">
#
#
#               423%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               29%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               7519%
#
#
#
#             </div>, <div class="important_num1">
#
#                9%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               201%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               24%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#                76%
#
#             </div>, <div class="important_num1">
#
#
#               38%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               18%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               210%
#
#
#
#             </div>, <div class="important_num1">
#
#                4%
#
#             </div>]
# [<div class="important_num1">
#
#
#               1530%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               58%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                26%
#
#             </div>, <div class="important_num1">
#
#                47%
#
#             </div>]
# [<div class="important_num1">
#
#
# ...
#
#
#               463%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               25%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               1387%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               93%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               119%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               14%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               198%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               443%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               16%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               482%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               42%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               42%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               229%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               39%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                15%
#
#             </div>, <div class="important_num1">
#
#                27%
#
#             </div>]
# [<div class="important_num1">
#
#                90%
#
#             </div>, <div class="important_num1">
#
#                38%
#
#             </div>]
# [<div class="important_num1">
#
#
#               231%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               37%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                30%
#
#             </div>]
# [<div class="important_num1">
#
#
#               96%
#
#
#
#             </div>, <div class="important_num1">
#
#                46%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#                74%
#
#             </div>]
# [<div class="important_num1">
#
#
#               98%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               3%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               400%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               56%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               21%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               540%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               273%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               441%
#
#
#
#             </div>, <div class="important_num1">
#
#                28%
#
#             </div>]
# [<div class="important_num1">
#
#
#               61%
#
#
#
#             </div>, <div class="important_num1">
#
#                49%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               255%
#
#
#
#             </div>, <div class="important_num1">
#
#                14%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               124%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               3990%
#
#
#
#             </div>, <div class="important_num1">
#
#                2%
#
#             </div>]
# [<div class="important_num1">
#
#
#               1180%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               86%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               402%
#
#
#
#             </div>, <div class="important_num1">
#
#                23%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               47%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               213%
#
#
#
#             </div>, <div class="important_num1">
#
#                5%
#
#             </div>]
# [<div class="important_num1">
#
#
#               494%
#
#
#
#             </div>, <div class="important_num1">
#
#                20%
#
#             </div>]
# [<div class="important_num1">
#
#
#               836%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               59%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#                62%
#
#             </div>, <div class="important_num1">
#
#
#               92%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               173%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               29%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               1083%
#
#
#
#             </div>, <div class="important_num1">
#
#                1%
#
#             </div>]
# [<div class="important_num1">
#
#
#               403%
#
#
#
#             </div>, <div class="important_num1">
#
#                64%
#
#             </div>]
# [<div class="important_num1">
#
#
#               491%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               28%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               657%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               28%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               171%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               7%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               512%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               41%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               96%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               233%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               96%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               2%
#
#
#
#             </div>, <div class="important_num1">
#
#                18%
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               142%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               67%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#
#               32%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               70%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               2%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               648%
#
#
#
#             </div>, <div class="important_num1">
#
#                81%
#
#             </div>]
# [<div class="important_num1">
#
#
#               299%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               39%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               707%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               40%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               95%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               112%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#
#               322%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               13%
#
#
#
#             </div>]
# [<div class="important_num1">
#
#             N/A
#
#             </div>, <div class="important_num1">
#
#             N/A
#
#             </div>]
# [<div class="important_num1">
#
#
#               2788%
#
#
#
#             </div>, <div class="important_num1">
#
#
#               7%
#
#
#
#             </div>]
# Error found for http://force.nj.com/database/pd-dept/hi-nella-camden
# Error found for http://force.nj.com/database/pd-dept/lawnside-camden
# Error found for http://force.nj.com/database/pd-dept/pine%20valley-camden
# Error found for http://force.nj.com/database/pd-dept/franklin-hunterdon
# Error found for http://force.nj.com/database/pd-dept/tewksbury-hunterdon
# Error found for http://force.nj.com/database/pd-dept/elmer-salem
# Error found for http://force.nj.com/database/pd-dept/holland-hunterdon
# Error found for http://force.nj.com/database/pd-dept/new-hanover-burlington
# Error found for http://force.nj.com/database/pd-dept/buena-vista-atlantic
# Error found for http://force.nj.com/database/pd-dept/corbin-city-atlantic
# Error found for http://force.nj.com/database/pd-dept/estell-manor-atlantic
# Error found for http://force.nj.com/database/pd-dept/folsom-atlantic
# Error found for http://force.nj.com/database/pd-dept/port-republic-city-atlantic
# Error found for http://force.nj.com/database/pd-dept/weymouth-township-atlantic
# Error found for http://force.nj.com/database/pd-dept/wrightstown-burlington
# Error found for http://force.nj.com/database/pd-dept/woodland-burlington
# Error found for http://force.nj.com/database/pd-dept/bass-river-burlington
# Error found for http://force.nj.com/database/pd-dept/hainesport-burlington
# Error found for http://force.nj.com/database/pd-dept/tabernacle-burlington
# Error found for http://force.nj.com/database/pd-dept/southampton-burlington
# Error found for http://force.nj.com/database/pd-dept/shamong-burlington
# Error found for http://force.nj.com/database/pd-dept/washington-burlington
# Error found for http://force.nj.com/database/pd-dept/dennis-cape-may
# Error found for http://force.nj.com/database/pd-dept/upper-cape-may
# Error found for http://force.nj.com/database/pd-dept/woodbine-cape-may
# Error found for http://force.nj.com/database/pd-dept/commercial-cumberland
# Error found for http://force.nj.com/database/pd-dept/deerfield-cumberland
# Error found for http://force.nj.com/database/pd-dept/downe-cumberland
# Error found for http://force.nj.com/database/pd-dept/fairfield-cumberland
# Error found for http://force.nj.com/database/pd-dept/greenwich-township-cumberland
# Error found for http://force.nj.com/database/pd-dept/hopewell-cumberland
# Error found for http://force.nj.com/database/pd-dept/lawrence-township-cumberland
# Error found for http://force.nj.com/database/pd-dept/maurice-river-cumberland
# Error found for http://force.nj.com/database/pd-dept/shiloh-borough-cumberland
# Error found for http://force.nj.com/database/pd-dept/stow-creek-cumberland
# Error found for http://force.nj.com/database/pd-dept/upper-deerfield-cumberland
# Error found for http://force.nj.com/database/pd-dept/alexandria-hunterdon
# Error found for http://force.nj.com/database/pd-dept/bethlehem-hunterdon
# Error found for http://force.nj.com/database/pd-dept/bloomsbury-borough-hunterdon
# Error found for http://force.nj.com/database/pd-dept/east-amwell-hunterdon
# Error found for http://force.nj.com/database/pd-dept/glen-gardner-borough-hunterdon
# Error found for http://force.nj.com/database/pd-dept/hampton-hunterdon
# Error found for http://force.nj.com/database/pd-dept/kingwood-hunterdon
# Error found for http://force.nj.com/database/pd-dept/lebanon-borough-hunterdon
# Error found for http://force.nj.com/database/pd-dept/milford-borough-hunterdon
# Error found for http://force.nj.com/database/pd-dept/stockton-borough-hunterdon
# Error found for http://force.nj.com/database/pd-dept/union-hunterdon
# Error found for http://force.nj.com/database/pd-dept/farmingdale-monmouth
# Error found for http://force.nj.com/database/pd-dept/millstone-monmouth
# Error found for http://force.nj.com/database/pd-dept/roosevelt-monmouth
# Error found for http://force.nj.com/database/pd-dept/shrewsbury-township-monmouth
# Error found for http://force.nj.com/database/pd-dept/upper-freehold-monmouth
# Error found for http://force.nj.com/database/pd-dept/victory-gardens-morris
# Error found for http://force.nj.com/database/pd-dept/eagleswood-ocean
# Error found for http://force.nj.com/database/pd-dept/alloway-salem
# Error found for http://force.nj.com/database/pd-dept/mannington-salem
# Error found for http://force.nj.com/database/pd-dept/oldmans-salem
# Error found for http://force.nj.com/database/pd-dept/pilesgrove-salem
# Error found for http://force.nj.com/database/pd-dept/pittsgrove-salem
# Error found for http://force.nj.com/database/pd-dept/quinton-salem
# Error found for http://force.nj.com/database/pd-dept/upper-pittsgrove-salem
# Error found for http://force.nj.com/database/pd-dept/millstone-somerset
# Error found for http://force.nj.com/database/pd-dept/rocky-hill-somerset
# Error found for http://force.nj.com/database/pd-dept/andover-borough-sussex
# Error found for http://force.nj.com/database/pd-dept/branchville-borough-sussex
# Error found for http://force.nj.com/database/pd-dept/frankford-sussex
# Error found for http://force.nj.com/database/pd-dept/fredon-sussex
# Error found for http://force.nj.com/database/pd-dept/green-sussex
# Error found for http://force.nj.com/database/pd-dept/hampton-sussex
# Error found for http://force.nj.com/database/pd-dept/lafayette-sussex
# Error found for http://force.nj.com/database/pd-dept/montague-sussex
# Error found for http://force.nj.com/database/pd-dept/sandyston-sussex
# Error found for http://force.nj.com/database/pd-dept/stillwater-sussex
# Error found for http://force.nj.com/database/pd-dept/sussex-borough-sussex
# Error found for http://force.nj.com/database/pd-dept/walpack-township-sussex
# Error found for http://force.nj.com/database/pd-dept/wantage-sussex
# Error found for http://force.nj.com/database/pd-dept/allamuchy-warren
# Error found for http://force.nj.com/database/pd-dept/franklin-warren
# Error found for http://force.nj.com/database/pd-dept/frelinghuysen-warren
# Error found for http://force.nj.com/database/pd-dept/hardwick-township-warren
# Error found for http://force.nj.com/database/pd-dept/harmony-warren
# Error found for http://force.nj.com/database/pd-dept/hope-warren
# Error found for http://force.nj.com/database/pd-dept/knowlton-township-warren
# Error found for http://force.nj.com/database/pd-dept/liberty-township-warren
# Error found for http://force.nj.com/database/pd-dept/oxford-warren
# Error found for http://force.nj.com/database/pd-dept/white-warren
# []

# %%
df['important_numbers'] = important_numbers

# %%
clean_important_numbers = []
for element in important_numbers:
    if type(element) == str:
        clean_important_numbers.append([element])
    elif len(element) > 0:
        clean_important_numbers.append([el.text.strip() for el in element])
    else:
        clean_important_numbers.append(["No numbers found"])

# %%
df['important_numbers'] = clean_important_numbers

# %%
mask_2_n = df['important_numbers'].apply(len) == 2

# %%
df[mask_2_n]['important_numbers']
# Out:
# ['294%', '42%']

# %%
df[['likelihood_force_by_pop', 'likelihood_force_by_arrests']] = pd.DataFrame(df[mask_2_n]['important_numbers'].to_list(), columns=['likelihood_force_by_pop','likelihood_force_by_arrests'], index = df[mask_2_n].index)

# %%
df
# Out:
#                                name  \
# 0                Aberdeen, Monmouth
# 1                 Absecon, Atlantic
# 2                 Allendale, Bergen
# 3              Allenhurst, Monmouth
# 4               Allentown, Monmouth
# ..                              ...
# 542       Knowlton Township, Warren
# 543        Liberty Township, Warren
# 544                  Oxford, Warren
# 545                   White, Warren
# 546  New Jersey State Police (NJSP)
#
#                                             url  \
# 0           /database/pd-dept/aberdeen-monmouth
# 1            /database/pd-dept/absecon-atlantic
# 2            /database/pd-dept/allendale-bergen
# 3         /database/pd-dept/allenhurst-monmouth
# 4          /database/pd-dept/allentown-monmouth
# ..                                          ...
# 542  /database/pd-dept/knowlton-township-warren
# 543   /database/pd-dept/liberty-township-warren
# 544             /database/pd-dept/oxford-warren
# 545              /database/pd-dept/white-warren
# 546                      /database/pd-dept/njsp
#
#                                               full_url  \
# 0    http://force.nj.com/database/pd-dept/aberdeen-...
# 1    http://force.nj.com/database/pd-dept/absecon-a...
# 2    http://force.nj.com/database/pd-dept/allendale...
# 3    http://force.nj.com/database/pd-dept/allenhurs...
# 4    http://force.nj.com/database/pd-dept/allentown...
# ..                                                 ...
# 542  http://force.nj.com/database/pd-dept/knowlton-...
# 543  http://force.nj.com/database/pd-dept/liberty-t...
# 544  http://force.nj.com/database/pd-dept/oxford-wa...
# 545  http://force.nj.com/database/pd-dept/white-warren
# 546          http://force.nj.com/database/pd-dept/njsp
#
#                                      important_numbers  \
# 0                                          [294%, 42%]
# 1                                          [583%, 68%]
# 2                                            [N/A, 8%]
# 3                                           [N/A, N/A]
# 4                                           [N/A, N/A]
# ..                                                 ...
# 542  [Error found for http://force.nj.com/database/...
# 543  [Error found for http://force.nj.com/database/...
# 544  [Error found for http://force.nj.com/database/...
# 545  [Error found for http://force.nj.com/database/...
# 546                                 [No numbers found]
#
#     likelihood_force_by_pop likelihood_force_by_arrests
# 0                      294%                         42%
# 1                      583%                         68%
# 2                       N/A                          8%
# 3                       N/A                         N/A
# 4                       N/A                         N/A
# ..                      ...                         ...
# 542                     NaN                         NaN
# 543                     NaN                         NaN
# 544                     NaN                         NaN
# 545                     NaN                         NaN
# 546                     NaN                         NaN
#
# [547 rows x 6 columns]

# %%
df[df['important_numbers'].apply(len) == 1].head(10)
# Out:
#                        name                                      url  \
# 211       Logan, Gloucester       /database/pd-dept/logan-gloucester
# 235      Marlboro, Monmouth      /database/pd-dept/marlboro-monmouth
# 320  Perth Amboy, Middlesex  /database/pd-dept/perth-amboy-middlesex
# 365       Salem City, Salem       /database/pd-dept/salem-city-salem
# 403       Toms River, Ocean       /database/pd-dept/toms-river-ocean
# 418          Wall, Monmouth          /database/pd-dept/wall-monmouth
# 460        Hi-Nella, Camden        /database/pd-dept/hi-nella-camden
# 461        Lawnside, Camden        /database/pd-dept/lawnside-camden
# 462     Pine Valley, Camden   /database/pd-dept/pine%20valley-camden
# 463     Franklin, Hunterdon     /database/pd-dept/franklin-hunterdon
#
#                                               full_url  \
# 211  http://force.nj.com/database/pd-dept/logan-glo...
# 235  http://force.nj.com/database/pd-dept/marlboro-...
# 320  http://force.nj.com/database/pd-dept/perth-amb...
# 365  http://force.nj.com/database/pd-dept/salem-cit...
# 403  http://force.nj.com/database/pd-dept/toms-rive...
# 418  http://force.nj.com/database/pd-dept/wall-monm...
# 460  http://force.nj.com/database/pd-dept/hi-nella-...
# 461  http://force.nj.com/database/pd-dept/lawnside-...
# 462  http://force.nj.com/database/pd-dept/pine%20va...
# 463  http://force.nj.com/database/pd-dept/franklin-...
#
#                                      important_numbers  \
# 211                                             [201%]
# 235                                             [451%]
# 320                                              [65%]
# 365                                             [112%]
# 403                                             [482%]
# 418                                             [540%]
# 460  [Error found for http://force.nj.com/database/...
# 461  [Error found for http://force.nj.com/database/...
# 462  [Error found for http://force.nj.com/database/...
# 463  [Error found for http://force.nj.com/database/...
#
#     likelihood_force_by_pop likelihood_force_by_arrests
# 211                     NaN                         NaN
# 235                     NaN                         NaN
# 320                     NaN                         NaN
# 365                     NaN                         NaN
# 403                     NaN                         NaN
# 418                     NaN                         NaN
# 460                     NaN                         NaN
# 461                     NaN                         NaN
# 462                     NaN                         NaN
# 463                     NaN                         NaN

# %%
mask_1n = (df['important_numbers'].apply(len) == 1) & (df['important_numbers'].apply(lambda x: x[0]).str.startswith("Error") == False) & (df['important_numbers'].apply(lambda x: x[0]).str.startswith("No") == False)

# %%
df.loc[mask_1n, 'likelihood_force_by_pop'] = df[mask_1n]['important_numbers'].apply(lambda x: x[0])

# %%
df[mask_1n]
# Out:
#                        name                                      url  \
# 211       Logan, Gloucester       /database/pd-dept/logan-gloucester
# 235      Marlboro, Monmouth      /database/pd-dept/marlboro-monmouth
# 320  Perth Amboy, Middlesex  /database/pd-dept/perth-amboy-middlesex
# 365       Salem City, Salem       /database/pd-dept/salem-city-salem
# 403       Toms River, Ocean       /database/pd-dept/toms-river-ocean
# 418          Wall, Monmouth          /database/pd-dept/wall-monmouth
#
#                                               full_url important_numbers  \
# 211  http://force.nj.com/database/pd-dept/logan-glo...            [201%]
# 235  http://force.nj.com/database/pd-dept/marlboro-...            [451%]
# 320  http://force.nj.com/database/pd-dept/perth-amb...             [65%]
# 365  http://force.nj.com/database/pd-dept/salem-cit...            [112%]
# 403  http://force.nj.com/database/pd-dept/toms-rive...            [482%]
# 418  http://force.nj.com/database/pd-dept/wall-monm...            [540%]
#
#     likelihood_force_by_pop likelihood_force_by_arrests
# 211                    201%                         NaN
# 235                    451%                         NaN
# 320                     65%                         NaN
# 365                    112%                         NaN
# 403                    482%                         NaN
# 418                    540%                         NaN

# %%
df.to_csv(INTERIM_DATA / 'draft-data.csv', encoding = 'utf-8', index = False)

# %%
df.head()
# Out:
#                    name                                    url  \
# 0    Aberdeen, Monmouth    /database/pd-dept/aberdeen-monmouth
# 1     Absecon, Atlantic     /database/pd-dept/absecon-atlantic
# 2     Allendale, Bergen     /database/pd-dept/allendale-bergen
# 3  Allenhurst, Monmouth  /database/pd-dept/allenhurst-monmouth
# 4   Allentown, Monmouth   /database/pd-dept/allentown-monmouth
#
#                                             full_url important_numbers  \
# 0  http://force.nj.com/database/pd-dept/aberdeen-...       [294%, 42%]
# 1  http://force.nj.com/database/pd-dept/absecon-a...       [583%, 68%]
# 2  http://force.nj.com/database/pd-dept/allendale...         [N/A, 8%]
# 3  http://force.nj.com/database/pd-dept/allenhurs...        [N/A, N/A]
# 4  http://force.nj.com/database/pd-dept/allentown...        [N/A, N/A]
#
#   likelihood_force_by_pop likelihood_force_by_arrests
# 0                    294%                         42%
# 1                    583%                         68%
# 2                     N/A                          8%
# 3                     N/A                         N/A
# 4                     N/A                         N/A

# %%
mask_likelihood_empty = (df['likelihood_force_by_arrests'].isnull()) & (df['likelihood_force_by_pop'].isnull())

# %%
df.loc[mask_likelihood_empty, 'no_data_found'] = 'No data found'

# %%
df.tail()
# Out:
#                                name  \
# 542       Knowlton Township, Warren
# 543        Liberty Township, Warren
# 544                  Oxford, Warren
# 545                   White, Warren
# 546  New Jersey State Police (NJSP)
#
#                                             url  \
# 542  /database/pd-dept/knowlton-township-warren
# 543   /database/pd-dept/liberty-township-warren
# 544             /database/pd-dept/oxford-warren
# 545              /database/pd-dept/white-warren
# 546                      /database/pd-dept/njsp
#
#                                               full_url  \
# 542  http://force.nj.com/database/pd-dept/knowlton-...
# 543  http://force.nj.com/database/pd-dept/liberty-t...
# 544  http://force.nj.com/database/pd-dept/oxford-wa...
# 545  http://force.nj.com/database/pd-dept/white-warren
# 546          http://force.nj.com/database/pd-dept/njsp
#
#                                      important_numbers  \
# 542  [Error found for http://force.nj.com/database/...
# 543  [Error found for http://force.nj.com/database/...
# 544  [Error found for http://force.nj.com/database/...
# 545  [Error found for http://force.nj.com/database/...
# 546                                 [No numbers found]
#
#     likelihood_force_by_pop likelihood_force_by_arrests        No data  \
# 542                     NaN                         NaN  No data found
# 543                     NaN                         NaN  No data found
# 544                     NaN                         NaN  No data found
# 545                     NaN                         NaN  No data found
# 546                     NaN                         NaN  No data found
#
#      no_data_found
# 542  No data found
# 543  No data found
# 544  No data found
# 545  No data found
# 546  No data found

# %%
df.columns
# Out:
# Index(['name', 'url', 'full_url', 'important_numbers',
#        'likelihood_force_by_pop', 'likelihood_force_by_arrests', 'No data',
#        'no_data_found'],
#       dtype='object')

# %%
voi = [
    'name', 
    'url', 
    'full_url', 
    'likelihood_force_by_pop', 
    'likelihood_force_by_arrests', 
    'no_data_found'
]

# %%
final_df = df[voi]

# %%
final_df.columns = ['dept_name', 'relative_url', 'full_url', 'likelihood_force_by_pop', 'likelihood_force_by_arrests', 'no_data_found']

# %%
final_df.to_csv(PROCESSED_DATA / f"force-nj-com-{today}.csv", encoding = 'utf-8', index = False)
